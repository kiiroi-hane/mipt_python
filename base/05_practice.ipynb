# %% [markdown]
# <div style="text-align: center; padding: 30px 10px;">
#
# <h1 style="color:#ff7500; font-size: 24px; margin-bottom: 10px;">
# МФТИ ФПМИ
# </h1>
#
# <h2 style="font-size: 30px; margin-top: 5px;">
# Практикум Python - Основной Поток
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# <h3 style="font-size: 36px;">
# 5. Dataclass, контекстные менеджеры. Практика.
# </h3>
#
# <p style="margin-top: 20px;">
# <strong>Дата:</strong> 03-05 марта 2026 года<br>
# </p>
#
# <p style="margin-top: 25px;">
# Данный ноутбук является частью серии семинаров по курсу
# <em>«Практикум Python»</em> и предназначен для учебных и образовательных целей.
# </p>
#
# </div>

# %% [markdown]
# Гильдия приключенцев Фаэруна зовёт на помощь! Уилл Рейвенгард хочет наконец-то внести порядок в хаос квестов во Вратах Балдура - помоги ему :)

# %% [markdown]
# ## Задача 1. Квесты.
#
# Создай класс `Quest` с полями `title`, `difficulty` (значение Enum'а), `reward`, используя `@dataclass`.
#
# Надо ли использовать `@total_ordering`, чтобы была возможность сортировать квесты? Сделай так, чтобы квесты сортировались сначала по сложности, потом по названию.

# %%
# TODO

# %% [markdown]
# ## Задача 2. Приключенцы.
#
# Создай класс `Adventurer` с полями `name`, `level`, `active_quests` с помощью `@dataclass`.
#
#
# Получится ли создать список `active_quests` так легко? Для чего нужен `field(default_factory=list)`?

# %%
# TODO

# %% [markdown]
# ## Задача 3. Гильдия.
#
# Создай класс `Guild` с полями `members`, `free_quests`.
#
# Реализуй методы:
#
# - `take_quest(contractor: Adventurer, quest: Quest)` - выдаёт квест приключенцу и удаляет его из списка свободных квестов.
# - `to_json(filename)` - загружает в файл в формате JSON информацию о гильдии.
# - `load_from_json(filename)` - достаём из файла под названием `filename` формата JSON гильдию.
#
# Подсказка: используй `dataclasses.asdict()` или его аналоги.

# %%
# TODO

# %% [markdown]
# ## Задача 4. Контекстный менеджер гильдии
#
# Сделай класс `Guild` контекстным менеджером - определи `__enter__`, `__exit__`.

# %%
# TODO
